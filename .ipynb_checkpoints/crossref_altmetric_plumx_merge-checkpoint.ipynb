# %%
import pandas as pd
import numpy as np
from impact_factor.core import Factor

# %%
crossref = pd.read_csv('TXST_crossref/TXST_crossref_2000.csv')  
years = np.arange(2001, 2025, 1)
for year in years:
    filepath = 'TXST_crossref/TXST_crossref_'+str(year)+'.csv'
    papers = pd.read_csv(filepath)  
    crossref = pd.concat([crossref, papers])

# %%
crossref = crossref.fillna(0)

# %%
crossref.shape
# Out:
# (25000, 26)

# %%
crossref = crossref.reset_index()
crossref = crossref.drop(['index', 'CitesURL', 'QueryDate', 'GSRank', 'CitationURL'], axis=1)
crossref["impact_factor"] = None

# %%
crossref.shape
# Out:
# (25000, 23)

# %%
crossref
# Out:
#        Cites                                            Authors  \
# 0          6  K. P. Wiederhold, Y. Yamaguchi, A. Ayala, M. M...
# 1         74  Carolyn A. Marr, Linda French, Donna Thompson,...
# 2         34  Shiela J. Heater, Mary W. Carrano, Douglas Rai...
# 3         31  Walter E. Rudzinski, Tejraj M. Aminabhavi, Ste...
# 4         38  John P Tiefenbacher, Frederick A Day, Joseph A...
# ...      ...                                                ...
# 24995      2  Nancy R. Downing, Katherine N. Scafide, Zahra ...
# 24996      0  Atin Pramanik, Preeti Lata Mahapatra, Raphael ...
# 24997      0                      Mei-ki Chan, Aprile D. Benner
# 24998      0  Brian M. Casey, Lisa Mele, Alan M. Peaceman, M...
# 24999      0  Contessa A. Ricci, Benjamin Crysup, Nicole R. ...
#
#                                                    Title  Year  \
# 0      Ti/TiN coatings for microfabricated cantilever...  2000
# 1      Animal-Assisted Therapy in Psychiatric Rehabil...  2000
# 2      Interaction of Oxo-Bridged Vanadium(III) Phena...  2000
# 3      Isolation and Characterization of the Saturate...  2000
# 4      Attributes of repeat visitors to small tourist...  2000
# ...                                                  ...   ...
# 24995  Visibility of inflicted bruises by alternate l...  2024
# 24996  Biotene: Earth-Abundant 2D Material as Sustain...  2024
# 24997  A consideration of racial/ethnic diversity con...  2024
# 24998  Association of Mild Iodine Insufficiency durin...  2024
# 24999  Machine Learning: a new era for cardiovascular...  2024
#
#                                                   Source  \
# 0      Journal of Vacuum Science &amp; Technology B: ...
# 1                                             Anthrozoös
# 2                                    Inorganic Chemistry
# 3                                     Energy &amp; Fuels
# 4                             The Social Science Journal
# ...                                                  ...
# 24995                       Journal of Forensic Sciences
# 24996             ACS Applied Materials &amp; Interfaces
# 24997                           Educational Psychologist
# 24998                   American Journal of Perinatology
# 24999  American Journal of Physiology-Heart and Circu...
#
#                              Publisher  \
# 0              American Vacuum Society
# 1                   Informa UK Limited
# 2      American Chemical Society (ACS)
# 3      American Chemical Society (ACS)
# 4                   Informa UK Limited
# ...                                ...
# 24995                            Wiley
# 24996  American Chemical Society (ACS)
# 24997               Informa UK Limited
# 24998           Georg Thieme Verlag KG
# 24999   American Physiological Society
#
#                                             ArticleURL             Type  \
# 0                   http://dx.doi.org/10.1116/1.591356  journal-article
# 1         http://dx.doi.org/10.2752/089279300786999950  journal-article
# 2                  http://dx.doi.org/10.1021/ic000389r  journal-article
# 3                  http://dx.doi.org/10.1021/ef990207h  journal-article
# 4      http://dx.doi.org/10.1016/s0362-3319(00)00063-x  journal-article
# ...                                                ...              ...
# 24995        http://dx.doi.org/10.1111/1556-4029.15481  journal-article
# 24996         http://dx.doi.org/10.1021/acsami.3c15664  journal-article
# 24997  http://dx.doi.org/10.1080/00461520.2024.2376020  journal-article
# 24998         http://dx.doi.org/10.1055/s-0043-1778037  journal-article
# 24999    http://dx.doi.org/10.1152/ajpheart.00149.2024  journal-article
#
#                                  DOI       ISSN  ...  EndPage  ECC  \
# 0                   10.1116/1.591356  1071-1023  ...   1186.0    6
# 1         10.2752/089279300786999950  0892-7936  ...     47.0   74
# 2                  10.1021/ic000389r  0020-1669  ...   3889.0   34
# 3                  10.1021/ef990207h  0887-0624  ...    844.0   31
# 4      10.1016/s0362-3319(00)00063-x  0362-3319  ...    308.0   38
# ...                              ...        ...  ...      ...  ...
# 24995        10.1111/1556-4029.15481  0022-1198  ...    887.0    2
# 24996         10.1021/acsami.3c15664  1944-8244  ...   2427.0    0
# 24997  10.1080/00461520.2024.2376020  0046-1520  ...     19.0    0
# 24998         10.1055/s-0043-1778037  0735-1631  ...      0.0    0
# 24999    10.1152/ajpheart.00149.2024  0363-6135  ...      0.0    0
#
#        CitesPerYear  CitesPerAuthor  AuthorCount  Age  \
# 0              0.25               1            6   24
# 1              3.08               9            8   24
# 2              1.42               4            8   24
# 3              1.29               8            4   24
# 4              1.58              13            3   24
# ...             ...             ...          ...  ...
# 24995          2.00               1            4    1
# 24996          0.00               0           14    1
# 24997          0.00               0            2    1
# 24998          0.00               0           14    1
# 24999          0.00               0            8    1
#
#                                                 Abstract  \
# 0      We report the successful sputter coating of mi...
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 24995  Abstract: Difficulty visualizing bruises resul...
# 24996                                                  0
# 24997                                                  0
# 24998  Objective Our objective was to evaluate whethe...
# 24999  The maternal cardiovascular system undergoes f...
#
#                                              FullTextURL  RelatedURL  \
# 0      https://pubs.aip.org/avs/jvb/article-pdf/18/3/...         0.0
# 1      https://www.tandfonline.com/doi/pdf/10.2752/08...         0.0
# 2         https://pubs.acs.org/doi/pdf/10.1021/ic000389r         0.0
# 3         https://pubs.acs.org/doi/pdf/10.1021/ef990207h         0.0
# 4      https://api.elsevier.com/content/article/PII:S...         0.0
# ...                                                  ...         ...
# 24995  https://onlinelibrary.wiley.com/doi/pdf/10.111...         0.0
# 24996  https://pubs.acs.org/doi/pdf/10.1021/acsami.3c...         0.0
# 24997  https://www.tandfonline.com/doi/pdf/10.1080/00...         0.0
# 24998  http://www.thieme-connect.de/products/ejournal...         0.0
# 24999  https://journals.physiology.org/doi/pdf/10.115...         0.0
#
#       impact_factor
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# ...             ...
# 24995          None
# 24996          None
# 24997          None
# 24998          None
# 24999          None
#
# [25000 rows x 23 columns]

# %%
factor = Factor()
for i in range(0, len(crossref)):
    if i % 100 == 0:
        print("On iteration ", i)
    if crossref.loc[i, 'Source'] != 0:
        factor_dict = factor.search(crossref.loc[i, 'Source'])
        if len(factor_dict)>0:
            crossref.loc[i, 'impact_factor'] = factor_dict[0]['factor']
        else:
            crossref.loc[i, 'impact_factor'] = 0
    else:
        crossref.loc[i, 'impact_factor'] = 0
# Out:
# On iteration  0
# On iteration  100
# On iteration  200
# On iteration  300
# On iteration  400
# On iteration  500
# On iteration  600
# On iteration  700
# On iteration  800
# On iteration  900
# On iteration  1000
# On iteration  1100
# On iteration  1200
# On iteration  1300
# On iteration  1400
# On iteration  1500
# On iteration  1600
# On iteration  1700
# On iteration  1800
# On iteration  1900
# On iteration  2000
# On iteration  2100
# On iteration  2200
# On iteration  2300
# On iteration  2400
# On iteration  2500
# On iteration  2600
# On iteration  2700
# On iteration  2800
# On iteration  2900
# On iteration  3000
# On iteration  3100
# On iteration  3200
# On iteration  3300
# On iteration  3400
# On iteration  3500
# On iteration  3600
# On iteration  3700
# On iteration  3800
# On iteration  3900
# On iteration  4000
# On iteration  4100
# On iteration  4200
# On iteration  4300
# On iteration  4400
# On iteration  4500
# On iteration  4600
# On iteration  4700
# On iteration  4800
# On iteration  4900
# On iteration  5000
# On iteration  5100
# On iteration  5200
# On iteration  5300
# On iteration  5400
# On iteration  5500
# On iteration  5600
# On iteration  5700
# On iteration  5800
# On iteration  5900
# On iteration  6000
# On iteration  6100
# On iteration  6200
# On iteration  6300
# On iteration  6400
# On iteration  6500
# On iteration  6600
# On iteration  6700
# On iteration  6800
# On iteration  6900
# On iteration  7000
# On iteration  7100
# On iteration  7200
# On iteration  7300
# On iteration  7400
# On iteration  7500
# On iteration  7600
# On iteration  7700
# On iteration  7800
# On iteration  7900
# On iteration  8000
# On iteration  8100
# On iteration  8200
# On iteration  8300
# On iteration  8400
# On iteration  8500
# On iteration  8600
# On iteration  8700
# On iteration  8800
# On iteration  8900
# On iteration  9000
# On iteration  9100
# On iteration  9200
# On iteration  9300
# On iteration  9400
# On iteration  9500
# On iteration  9600
# On iteration  9700
# On iteration  9800
# On iteration  9900
# On iteration  10000
# On iteration  10100
# On iteration  10200
# On iteration  10300
# On iteration  10400
# On iteration  10500
# On iteration  10600
# On iteration  10700
# On iteration  10800
# On iteration  10900
# On iteration  11000
# On iteration  11100
# On iteration  11200
# On iteration  11300
# On iteration  11400
# On iteration  11500
# On iteration  11600
# On iteration  11700
# On iteration  11800
# On iteration  11900
# On iteration  12000
# On iteration  12100
# On iteration  12200
# On iteration  12300
# On iteration  12400
# On iteration  12500
# On iteration  12600
# On iteration  12700
# On iteration  12800
# On iteration  12900
# On iteration  13000
# On iteration  13100
# On iteration  13200
# On iteration  13300
# On iteration  13400
# On iteration  13500
# On iteration  13600
# On iteration  13700
# On iteration  13800
# On iteration  13900
# On iteration  14000
# On iteration  14100
# On iteration  14200
# On iteration  14300
# On iteration  14400
# On iteration  14500
# On iteration  14600
# On iteration  14700
# On iteration  14800
# On iteration  14900
# On iteration  15000
# On iteration  15100
# On iteration  15200
# On iteration  15300
# On iteration  15400
# On iteration  15500
# On iteration  15600
# On iteration  15700
# On iteration  15800
# On iteration  15900
# On iteration  16000
# On iteration  16100
# On iteration  16200
# On iteration  16300
# On iteration  16400
# On iteration  16500
# On iteration  16600
# On iteration  16700
# On iteration  16800
# On iteration  16900
# On iteration  17000
# On iteration  17100
# On iteration  17200
# On iteration  17300
# On iteration  17400
# On iteration  17500
# On iteration  17600
# On iteration  17700
# On iteration  17800
# On iteration  17900
# On iteration  18000
# On iteration  18100
# On iteration  18200
# On iteration  18300
# On iteration  18400
# On iteration  18500
# On iteration  18600
# On iteration  18700
# On iteration  18800
# On iteration  18900
# On iteration  19000
# On iteration  19100
# On iteration  19200
# On iteration  19300
# On iteration  19400
# On iteration  19500
# On iteration  19600
# On iteration  19700
# On iteration  19800
# On iteration  19900
# On iteration  20000
# On iteration  20100
# On iteration  20200
# On iteration  20300
# On iteration  20400
# On iteration  20500
# On iteration  20600
# On iteration  20700
# On iteration  20800
# On iteration  20900
# On iteration  21000
# On iteration  21100
# On iteration  21200
# On iteration  21300
# On iteration  21400
# On iteration  21500
# On iteration  21600
# On iteration  21700
# On iteration  21800
# On iteration  21900
# On iteration  22000
# On iteration  22100
# On iteration  22200
# On iteration  22300
# On iteration  22400
# On iteration  22500
# On iteration  22600
# On iteration  22700
# On iteration  22800
# On iteration  22900
# On iteration  23000
# On iteration  23100
# On iteration  23200
# On iteration  23300
# On iteration  23400
# On iteration  23500
# On iteration  23600
# On iteration  23700
# On iteration  23800
# On iteration  23900
# On iteration  24000
# On iteration  24100
# On iteration  24200
# On iteration  24300
# On iteration  24400
# On iteration  24500
# On iteration  24600
# On iteration  24700
# On iteration  24800
# On iteration  24900

# %%
crossref.shape
# Out:
# (25000, 23)

# %%
crossref.to_csv("crossref_allyears.csv", index=False)
crossref.shape
# Out:
# (25000, 23)

# %%
altmetrics = pd.read_csv('altmetrics_tabular_cleaned.csv')
altmetrics.shape
# Out:
# (8173, 62)

# %%
plumx = pd.read_csv('plumx_metrics_tabular_cleaned.csv')
plumx.shape
# Out:
# (24515, 20)

# %%
merge_plumx = pd.merge(crossref, plumx, how='left', left_on='DOI', right_on='doi_plumx')
merge_plumx.shape
# Out:
# (25000, 43)

# %%
merge = pd.merge(merge_plumx, altmetrics, how='left', left_on='DOI', right_on='doi_altmetrics')
merge.shape
# Out:
# (25000, 105)

# %%
merge
# Out:
#        Cites                                            Authors  \
# 0          6  K. P. Wiederhold, Y. Yamaguchi, A. Ayala, M. M...
# 1         74  Carolyn A. Marr, Linda French, Donna Thompson,...
# 2         34  Shiela J. Heater, Mary W. Carrano, Douglas Rai...
# 3         31  Walter E. Rudzinski, Tejraj M. Aminabhavi, Ste...
# 4         38  John P Tiefenbacher, Frederick A Day, Joseph A...
# ...      ...                                                ...
# 24995      2  Nancy R. Downing, Katherine N. Scafide, Zahra ...
# 24996      0  Atin Pramanik, Preeti Lata Mahapatra, Raphael ...
# 24997      0                      Mei-ki Chan, Aprile D. Benner
# 24998      0  Brian M. Casey, Lisa Mele, Alan M. Peaceman, M...
# 24999      0  Contessa A. Ricci, Benjamin Crysup, Nicole R. ...
#
#                                                    Title  Year  \
# 0      Ti/TiN coatings for microfabricated cantilever...  2000
# 1      Animal-Assisted Therapy in Psychiatric Rehabil...  2000
# 2      Interaction of Oxo-Bridged Vanadium(III) Phena...  2000
# 3      Isolation and Characterization of the Saturate...  2000
# 4      Attributes of repeat visitors to small tourist...  2000
# ...                                                  ...   ...
# 24995  Visibility of inflicted bruises by alternate l...  2024
# 24996  Biotene: Earth-Abundant 2D Material as Sustain...  2024
# 24997  A consideration of racial/ethnic diversity con...  2024
# 24998  Association of Mild Iodine Insufficiency durin...  2024
# 24999  Machine Learning: a new era for cardiovascular...  2024
#
#                                                   Source  \
# 0      Journal of Vacuum Science &amp; Technology B: ...
# 1                                             Anthrozoös
# 2                                    Inorganic Chemistry
# 3                                     Energy &amp; Fuels
# 4                             The Social Science Journal
# ...                                                  ...
# 24995                       Journal of Forensic Sciences
# 24996             ACS Applied Materials &amp; Interfaces
# 24997                           Educational Psychologist
# 24998                   American Journal of Perinatology
# 24999  American Journal of Physiology-Heart and Circu...
#
#                              Publisher  \
# 0              American Vacuum Society
# 1                   Informa UK Limited
# 2      American Chemical Society (ACS)
# 3      American Chemical Society (ACS)
# 4                   Informa UK Limited
# ...                                ...
# 24995                            Wiley
# 24996  American Chemical Society (ACS)
# 24997               Informa UK Limited
# 24998           Georg Thieme Verlag KG
# 24999   American Physiological Society
#
#                                             ArticleURL             Type  \
# 0                   http://dx.doi.org/10.1116/1.591356  journal-article
# 1         http://dx.doi.org/10.2752/089279300786999950  journal-article
# 2                  http://dx.doi.org/10.1021/ic000389r  journal-article
# 3                  http://dx.doi.org/10.1021/ef990207h  journal-article
# 4      http://dx.doi.org/10.1016/s0362-3319(00)00063-x  journal-article
# ...                                                ...              ...
# 24995        http://dx.doi.org/10.1111/1556-4029.15481  journal-article
# 24996         http://dx.doi.org/10.1021/acsami.3c15664  journal-article
# 24997  http://dx.doi.org/10.1080/00461520.2024.2376020  journal-article
# 24998         http://dx.doi.org/10.1055/s-0043-1778037  journal-article
# 24999    http://dx.doi.org/10.1152/ajpheart.00149.2024  journal-article
#
#                                  DOI       ISSN  ...  cohorts.com_altmetrics  \
# 0                   10.1116/1.591356  1071-1023  ...                     NaN
# 1         10.2752/089279300786999950  0892-7936  ...                     NaN
# 2                  10.1021/ic000389r  0020-1669  ...                     NaN
# 3                  10.1021/ef990207h  0887-0624  ...                     0.0
# 4      10.1016/s0362-3319(00)00063-x  0362-3319  ...                     NaN
# ...                              ...        ...  ...                     ...
# 24995        10.1111/1556-4029.15481  0022-1198  ...                     0.0
# 24996         10.1021/acsami.3c15664  1944-8244  ...                     0.0
# 24997  10.1080/00461520.2024.2376020  0046-1520  ...                     NaN
# 24998         10.1055/s-0043-1778037  0735-1631  ...                     0.0
# 24999    10.1152/ajpheart.00149.2024  0363-6135  ...                     1.0
#
#        cited_by_wikipedia_count_altmetrics  cited_by_qna_count_altmetrics  \
# 0                                      NaN                            NaN
# 1                                      NaN                            NaN
# 2                                      NaN                            NaN
# 3                                      0.0                            0.0
# 4                                      NaN                            NaN
# ...                                    ...                            ...
# 24995                                  0.0                            0.0
# 24996                                  0.0                            0.0
# 24997                                  NaN                            NaN
# 24998                                  0.0                            0.0
# 24999                                  0.0                            0.0
#
#        cited_by_rh_count_altmetrics  cited_by_pinners_count_altmetrics  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               0.0                                0.0
# 4                               NaN                                NaN
# ...                             ...                                ...
# 24995                           0.0                                0.0
# 24996                           0.0                                0.0
# 24997                           NaN                                NaN
# 24998                           0.0                                0.0
# 24999                           0.0                                0.0
#
#        cited_by_gplus_count_altmetrics  cited_by_rdts_count_altmetrics  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  0.0                             0.0
# 4                                  NaN                             NaN
# ...                                ...                             ...
# 24995                              0.0                             0.0
# 24996                              0.0                             0.0
# 24997                              NaN                             NaN
# 24998                              0.0                             0.0
# 24999                              0.0                             0.0
#
#        cited_by_peer_review_sites_count_altmetrics  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              0.0
# 4                                              NaN
# ...                                            ...
# 24995                                          0.0
# 24996                                          0.0
# 24997                                          NaN
# 24998                                          0.0
# 24999                                          0.0
#
#        cited_by_linkedin_count_altmetrics cited_by_weibo_count_altmetrics
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     0.0                             0.0
# 4                                     NaN                             NaN
# ...                                   ...                             ...
# 24995                                 0.0                             0.0
# 24996                                 0.0                             0.0
# 24997                                 NaN                             NaN
# 24998                                 0.0                             0.0
# 24999                                 0.0                             0.0
#
# [25000 rows x 105 columns]

# %%
crossref.to_csv("allsources_merge.csv", index=False)
