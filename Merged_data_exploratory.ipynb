# %%
import pandas as pd

# %%
merge = pd.read_csv('merged_TXST_uncleaned.csv')
# Out:
# /var/folders/5d/khzhwx710sj17dmj05c_v5vm0000gn/T/ipykernel_20426/1130949885.py:1: DtypeWarning: Columns (27,129,146,147,150,152,154,155) have mixed types. Specify dtype option on import or set low_memory=False.
#   merge = pd.read_csv('merged_TXST_uncleaned.csv')

# %%
merge.head()
# Out:
#    Unnamed: 0  Cites                                            Authors  \
# 0           0    6.0  K. P. Wiederhold, Y. Yamaguchi, A. Ayala, M. M...
# 1           1   74.0  Carolyn A. Marr, Linda French, Donna Thompson,...
# 2           2   34.0  Shiela J. Heater, Mary W. Carrano, Douglas Rai...
# 3           3   31.0  Walter E. Rudzinski, Tejraj M. Aminabhavi, Ste...
# 4           4   38.0  John P Tiefenbacher, Frederick A Day, Joseph A...
#
#                                                Title    Year  \
# 0  Ti/TiN coatings for microfabricated cantilever...  2000.0
# 1  Animal-Assisted Therapy in Psychiatric Rehabil...  2000.0
# 2  Interaction of Oxo-Bridged Vanadium(III) Phena...  2000.0
# 3  Isolation and Characterization of the Saturate...  2000.0
# 4  Attributes of repeat visitors to small tourist...  2000.0
#
#                                               Source  \
# 0  Journal of Vacuum Science &amp; Technology B: ...
# 1                                         Anthrozoös
# ...
