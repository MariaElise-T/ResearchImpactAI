# %%
import pandas as pd
import seaborn as sns
import math
import numpy as np
pd.options.mode.chained_assignment = None

# %%
merge = pd.read_csv('THRC_final_indices.csv')

# %%
merge
# Out:
#                                              Authors  \
# 0  Zhu, Jie; Xun, Peng-Cheng; Kolencik, Marissa; ...
# 1  McAllister, Matthew J.; Gonzalez, Drew E.; Leo...
# 2                Ishola, Adenrele A.; Valles, Damian
# 3  Zhu, Jie; Chen, Cheng; Lu, Liping; Shikany, Ja...
# 4  Schepis, Ty S.; Rogers, Andrew H.; Munoz, Lili...
# 5  McAllister, Matthew J.; Gonzalez, Drew E.; Leo...
# 6  Engstrom, Curtiss W.; West, Brady T.; Schepis,...
#
#                                                Title  Year  \
# 0  Do B Vitamins Enhance the Effect of Omega-3 Po...  2022
# 1  Risk Factors for Cardiometabolic Disease in Pr...  2023
# 2  Enhancing Safety and Efficiency in Firefightin...  2023
# 3  Folate, Vitamin B <sub>6</sub> , and Vitamin B...  2023
# 4  Indirect effects of emotion regulation in the ...  2024
# 5  Firefighters With Higher Cardiorespiratory Fit...  2022
# 6  Does the approach used to measure sexual ident...  2024
#
#                                              Source  \
# ...

# %%
plt = sns.barplot(data=merge.sort_values(by="Short_Name"), x="Short_Name", y="overall_index")
plt.set_xticklabels(plt.get_xticklabels(), rotation=45)
plt.axhline(0.5, ls='--', c='red')
plt.set(xlabel ="", ylabel = "Overall Index", title ='THRC FF Papers')
# Out:
# C:\Users\met48\AppData\Local\Temp\ipykernel_31940\2313480393.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.set_xticklabels(plt.get_xticklabels(), rotation=45)
# [Text(0.5, 0, ''),
#  Text(0, 0.5, 'Overall Index'),
#  Text(0.5, 1.0, 'THRC FF Papers')]

# %%
plt = sns.barplot(data=merge.sort_values(by="Short_Name"), x="Short_Name", y="biblio_index")
plt.set_xticklabels(plt.get_xticklabels(), rotation=45)
plt.axhline(0.5, ls='--', c='red')
plt.set(xlabel ="", ylabel = "Bibliometric Index", title ='THRC FF Papers')
# Out:
# C:\Users\met48\AppData\Local\Temp\ipykernel_31940\201267605.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.set_xticklabels(plt.get_xticklabels(), rotation=45)
# [Text(0.5, 0, ''),
#  Text(0, 0.5, 'Bibliometric Index'),
#  Text(0.5, 1.0, 'THRC FF Papers')]

# %%
plt = sns.barplot(data=merge.sort_values(by="Short_Name"), x="Short_Name", y="sm_index")
plt.set_xticklabels(plt.get_xticklabels(), rotation=45)
plt.axhline(0.5, ls='--', c='red')
plt.set(xlabel ="", ylabel = "Social Media Index", title ='THRC FF Papers')
# Out:
# C:\Users\met48\AppData\Local\Temp\ipykernel_31940\3484103258.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.set_xticklabels(plt.get_xticklabels(), rotation=45)
# [Text(0.5, 0, ''),
#  Text(0, 0.5, 'Social Media Index'),
#  Text(0.5, 1.0, 'THRC FF Papers')]

# %%
plt = sns.barplot(data=merge.sort_values(by="Short_Name"), x="Short_Name", y="nm_index")
plt.set_xticklabels(plt.get_xticklabels(), rotation=45)
plt.axhline(0.5, ls='--', c='red')
plt.set(xlabel ="", ylabel = "News Index", title ='THRC FF Papers')
# Out:
# C:\Users\met48\AppData\Local\Temp\ipykernel_31940\840281212.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.set_xticklabels(plt.get_xticklabels(), rotation=45)
# [Text(0.5, 0, ''),
#  Text(0, 0.5, 'News Index'),
#  Text(0.5, 1.0, 'THRC FF Papers')]

# %%
plt = sns.barplot(data=merge.sort_values(by="Short_Name"), x="Short_Name", y="jif_index")
plt.set_xticklabels(plt.get_xticklabels(), rotation=45)
plt.axhline(0.5, ls='--', c='red')
plt.set(xlabel ="", ylabel = "Journal Impact Index", title ='THRC FF Papers')
# Out:
# C:\Users\met48\AppData\Local\Temp\ipykernel_31940\1612045589.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.set_xticklabels(plt.get_xticklabels(), rotation=45)
# [Text(0.5, 0, ''),
#  Text(0, 0.5, 'Journal Impact Index'),
#  Text(0.5, 1.0, 'THRC FF Papers')]

# %%
plt = sns.barplot(data=merge.sort_values(by="Short_Name"), x="Short_Name", y="misc_index")
plt.set_xticklabels(plt.get_xticklabels(), rotation=45)
plt.axhline(0.5, ls='--', c='red')
plt.set(xlabel ="", ylabel = "Misc Index", title ='THRC FF Papers')
# Out:
# C:\Users\met48\AppData\Local\Temp\ipykernel_31940\3272520311.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.set_xticklabels(plt.get_xticklabels(), rotation=45)
# [Text(0.5, 0, ''),
#  Text(0, 0.5, 'Misc Index'),
#  Text(0.5, 1.0, 'THRC FF Papers')]
