# %%
import pandas as pd
import seaborn as sns
import math
import numpy as np
# Out:
# C:\Users\met48\AppData\Local\Temp\ipykernel_5664\3620371138.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
merge = pd.read_csv('allsources_merge.csv')

# %%
merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Columns: 107 entries, Cites to cited_by_weibo_count_altmetrics
# dtypes: float64(84), int64(6), object(17)
# memory usage: 20.4+ MB

# %% [markdown]
# # Percent of zeroes in each column

# %%
pd.set_option("display.max_rows", 107)
print(merge[merge == 0].count(axis=0)/len(merge.index))
# Out:
# Cites                                                    0.19528
# Authors                                                  0.00000
# Title                                                    0.00000
# Year                                                     0.00000
# Source                                                   0.00000
# Publisher                                                0.00000
# ArticleURL                                               0.00000
# Type                                                     0.00000
# DOI                                                      0.00000
# ISSN                                                     0.00000
# Volume                                                   0.13264
# Issue                                                    0.18220
# StartPage                                                0.22352
# EndPage                                                  0.22352
# ...

# %% [markdown]
# # Check correlation

# %%
merge.select_dtypes((int, float)).corr()
# Out:
#                                                        Cites      Year  \
# Cites                                               1.000000 -0.146710
# Year                                               -0.146710  1.000000
# Volume                                             -0.017324  0.022365
# Issue                                               0.073199 -0.030240
# StartPage                                          -0.010800  0.042011
# EndPage                                            -0.010800  0.042011
# ECC                                                 1.000000 -0.146710
# CitesPerYear                                        0.937500 -0.042950
# CitesPerAuthor                                      0.887646 -0.110232
# AuthorCount                                         0.068036  0.012745
# Age                                                 0.146605 -0.999667
# RelatedURL                                               NaN       NaN
# ...
