# %%
import pandas as pd
import seaborn as sns
import math
import numpy as np

# %%
merge = pd.read_csv('allsources_merge.csv')

# %%
merge.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 107 columns):
#  #    Column                                                 Dtype
# ---   ------                                                 -----
#  0    Cites                                                  int64
#  1    Authors                                                object
#  2    Title                                                  object
#  3    Year                                                   int64
#  4    Source                                                 object
#  5    Publisher                                              object
#  6    ArticleURL                                             object
#  7    Type                                                   object
#  8    DOI                                                    object
#  9    ISSN                                                   object
#  10   Volume                                                 float64
#  11   Issue                                                  float64
#  12   StartPage                                              float64
#  13   EndPage                                                float64
#  14   ECC                                                    int64
#  15   CitesPerYear                                           float64
#  16   CitesPerAuthor                                         int64
#  17   AuthorCount                                            int64
#  18   Age                                                    int64
#  19   Abstract                                               object
#  20   FullTextURL                                            object
#  21   RelatedURL                                             float64
#  22   impact_factor                                          float64
#  23   Unnamed: 0_x                                           float64
#  24   doi_plumx                                              object
#  25   capture.READER_COUNT_plumx                             float64
#  26   citation.Scopus_plumx                                  float64
#  27   citation.CrossRef_plumx                                float64
#  28   citation.Academic Citation Index (ACI) - airiti_plumx  float64
#  29   citation.PubMed_plumx                                  float64
#  30   citation.Policy Citation_plumx                         float64
#  31   citation.Patent Families_plumx                         float64
#  32   mention.NEWS_COUNT_plumx                               float64
#  33   mention.FACEBOOK_COUNT_plumx                           float64
#  34   mention.REFERENCE_COUNT_plumx                          float64
#  35   citation.SSRN_plumx                                    float64
#  36   mention.ABSTRACT_VIEWS_plumx                           float64
#  37   mention.DOWNLOAD_COUNT_plumx                           float64
#  38   mention.ALL_BLOG_COUNT_plumx                           float64
#  39   citation.PubMed Guidelines_plumx                       float64
#  40   mention.FULL_TEXT_VIEWS_plumx                          float64
#  41   citation.SciELO_plumx                                  float64
#  42   capture.EXPORTS_SAVES_plumx                            float64
#  43   citation.CSCD_plumx                                    float64
#  44   Unnamed: 0_y                                           float64
#  45   doi_altmetrics                                         object
#  46   publisher_subjects_altmetrics                          object
#  47   cited_by_patents_count_altmetrics                      float64
#  48   cited_by_posts_count_altmetrics                        float64
#  49   cited_by_accounts_count_altmetrics                     float64
#  50   score_altmetrics                                       float64
#  51   url_altmetrics                                         object
#  52   scopus_subjects_altmetrics                             object
#  53   readers_count_altmetrics                               float64
#  54   details_url_altmetrics                                 object
#  55   context.all.count_altmetrics                           float64
#  56   context.all.mean_altmetrics                            float64
#  57   context.all.rank_altmetrics                            float64
#  58   context.all.pct_altmetrics                             float64
#  59   context.all.higher_than_altmetrics                     float64
#  60   context.journal.count_altmetrics                       float64
#  61   context.journal.mean_altmetrics                        float64
#  62   context.journal.rank_altmetrics                        float64
#  63   context.journal.pct_altmetrics                         float64
#  64   context.journal.higher_than_altmetrics                 float64
#  65   context.similar_age_3m.count_altmetrics                float64
#  66   context.similar_age_3m.mean_altmetrics                 float64
#  67   context.similar_age_3m.rank_altmetrics                 float64
#  68   context.similar_age_3m.pct_altmetrics                  float64
#  69   context.similar_age_3m.higher_than_altmetrics          float64
#  70   context.similar_age_journal_3m.count_altmetrics        float64
#  71   context.similar_age_journal_3m.mean_altmetrics         float64
#  72   context.similar_age_journal_3m.rank_altmetrics         float64
#  73   context.similar_age_journal_3m.pct_altmetrics          float64
#  74   context.similar_age_journal_3m.higher_than_altmetrics  float64
#  75   history.1y_altmetrics                                  float64
#  76   history.6m_altmetrics                                  float64
#  77   history.3m_altmetrics                                  float64
#  78   history.1m_altmetrics                                  float64
#  79   history.1w_altmetrics                                  float64
#  80   history.6d_altmetrics                                  float64
#  81   history.5d_altmetrics                                  float64
#  82   history.4d_altmetrics                                  float64
#  83   history.3d_altmetrics                                  float64
#  84   history.2d_altmetrics                                  float64
#  85   history.1d_altmetrics                                  float64
#  86   history.at_altmetrics                                  float64
#  87   readers.citeulike_altmetrics                           float64
#  88   readers.mendeley_altmetrics                            float64
#  89   readers.connotea_altmetrics                            float64
#  90   cited_by_policies_count_altmetrics                     float64
#  91   cited_by_msm_count_altmetrics                          float64
#  92   subjects_altmetrics                                    object
#  93   cited_by_fbwalls_count_altmetrics                      float64
#  94   cited_by_tweeters_count_altmetrics                     float64
#  95   cited_by_videos_count_altmetrics                       float64
#  96   cited_by_feeds_count_altmetrics                        float64
#  97   cohorts.com_altmetrics                                 float64
#  98   cited_by_wikipedia_count_altmetrics                    float64
#  99   cited_by_qna_count_altmetrics                          float64
#  100  cited_by_rh_count_altmetrics                           float64
#  101  cited_by_pinners_count_altmetrics                      float64
#  102  cited_by_gplus_count_altmetrics                        float64
#  103  cited_by_rdts_count_altmetrics                         float64
#  104  cited_by_peer_review_sites_count_altmetrics            float64
#  105  cited_by_linkedin_count_altmetrics                     float64
#  106  cited_by_weibo_count_altmetrics                        float64
# dtypes: float64(84), int64(6), object(17)
# memory usage: 20.4+ MB

# %% [markdown]
# # Bibliometrics section - Citations (all sources averaged) - 50%, engagement (abstract views, downloads, full text views, readers) - 50%
# Variables:
# - Cites
# - capture.READER_COUNT_plumx
# - citation.Scopus_plumx
# - citation.CrossRef_plumx
# - citation.PubMed_plumx
# - mention.ABSTRACT_VIEWS_plumx
# - mention.DOWNLOAD_COUNT_plumx
# - mention.FULL_TEXT_VIEWS_plumx
# - capture.EXPORTS_SAVES_plumx
# - readers.citeulike_altmetrics
# - readers.mendeley_altmetrics
# - readers.connotea_altmetrics

# %%
merge["Cites_per_year"] = merge["Cites"]/merge["Age"]
merge["Cites_rank"] = merge.Cites_per_year.rank(pct = True)

merge["readers_count_per_year"] = merge["readers_count"]/merge["Age"]
merge["readers_count_rank"] = merge.Cites_per_year.rank(pct = True)

merge["readers.mendeley_per_year"] = merge["readers.mendeley"]/merge["Age"]
merge["readers.mendeley_rank"] = merge.Cites_per_year.rank(pct = True)

# %%
merge["index_bibliometrics_raw"] = 0.5*merge["readers.mendeley_rank"]+0.25*merge["readers_count_rank"]+0.25*merge["readers.mendeley_rank"]

# %% [markdown]
# # Social media section - 33% cited_by_posts_count, 33% cited_by_accounts_count, 33% cited_by_tweeters_count

# %%
merge["tweets_per_year"] = merge["cited_by_tweeters_count"]/merge["Age"]
merge["tweets_rank"] = merge.tweets_per_year.rank(pct = True)

merge["posts_per_year"] = merge["cited_by_posts_count"]/merge["Age"]
merge["posts_rank"] = merge.posts_per_year.rank(pct = True)

merge["accounts_per_year"] = merge["cited_by_accounts_count"]/merge["Age"]
merge["accounts_rank"] = merge.accounts_per_year.rank(pct = True)

# %%
merge["index_social_media"] = (1/3)*merge["tweets_rank"]+(1/3)*merge["posts_rank"]+(1/3)*merge["accounts_rank"]

# %% [markdown]
# # News media
# Variables:
# -
# -
# -

# %%
merge["msm_per_year"] = merge["cited_by_msm_count"]/merge["Age"]
merge["news_index"] = merge.msm_per_year.rank(pct = True)

# %% [markdown]
# # Patents
# Variables:
# -
# -
# -

# %%
merge["patent_per_year"] = merge["cited_by_patents_count"]/merge["Age"]
merge["patent_index"] = merge.patent_per_year.rank(pct = True)

# %% [markdown]
# # Policies
# Variables:
# -
# -
# -

# %%
merge["policies_per_year"] = merge["cited_by_policies_count"]/merge["Age"]
merge["policies_index"] = merge.policies_per_year.rank(pct = True)

# %% [markdown]
# # Journal Impact Factor
# Variables:
# -
# -
# -

# %% [markdown]
# # Overall - 24% bibliometrics, 15% social media, 15% news media, 23% patents, 23% policies, 10% journal impact factor

# %%
merge["overall_index"] = 0.24*merge["index_bibliometrics"]+0.15*merge["index_social_media"]+0.15*merge['news_index']+0.23*merge['patent_index']+0.23*merge['policies_index']

# %%
merge[merge["overall_index"]>0.98]
# Out:
#        Unnamed: 0   Cites                                            Authors  \
# 7311       8003.0   936.0                CÃ©dric Feschotte, Ellen J. Pritham
# 8895       9708.0  2521.0  Mark S. Slaughter, Joseph G. Rogers, Carmelo A...
# 16024     17163.0   772.0  Marina Konopleva, Daniel A. Pollyea, Jalaja Po...
# 16033     17172.0   281.0  Milind Javle, Tanios Bekaiiâ€Saab, Apurva Jai...
#
#                                                    Title  Year  \
# 7311   DNA Transposons and the Evolution of Eukaryoti...  2007
# 8895   Advanced Heart Failure Treated with Continuous...  2009
# 16024  Efficacy and Biological Correlates of Response...  2016
# 16033  Biliary cancer: Utility of nextâ€generation s...  2016
#
#                                 Source  \
# 7311         Annual Review of Genetics
# 8895   New England Journal of Medicine
# 16024                 Cancer Discovery
# 16033                           Cancer
#
#                                              Publisher  \
# 7311                                    Annual Reviews
# 8895                     Massachusetts Medical Society
# 16024  American Association for Cancer Research (AACR)
# 16033                                            Wiley
#
#                                               ArticleURL  GSRank  \
# 7311   http://dx.doi.org/10.1146/annurev.genet.40.110...   878.0
# 8895             http://dx.doi.org/10.1056/nejmoa0909938   563.0
# 16024     http://dx.doi.org/10.1158/2159-8290.cd-16-0313   968.0
# 16033               http://dx.doi.org/10.1002/cncr.30254   977.0
#
#            QueryDate  ... accounts_per_year accounts_rank index_social_media  \
# 7311   7/25/24 13:48  ...          3.294118      0.960973           0.936729
# 8895   7/25/24 13:43  ...          2.933333      0.956793           0.928919
# 16024  7/25/24 11:45  ...          7.250000      0.975955           0.970382
# 16033  7/25/24 11:45  ...         12.875000      0.981609           0.973571
#
#        msm_per_year  news_index  policies_per_year  policies_index  \
# 7311       0.117647    0.969482           0.176471        0.995361
# 8895       0.800000    0.988172           0.266667        0.998171
# 16024      2.000000    0.993518           0.125000        0.990699
# 16033      9.625000    0.997862           0.125000        0.990699
#
#        patent_per_year  patent_index  overall_index
# 7311          2.176471      0.998216       0.982357
# 8895          0.866667      0.993933       0.984300
# 16024         2.375000      0.998528       0.990564
# 16033         0.875000      0.994178       0.989533
#
# [4 rows x 128 columns]

# %%
merge.to_csv("merged_data_with_indices.csv")
