# %%
import pandas as pd
import numpy as np
from scipy.stats import rankdata
import matplotlib.pyplot as plt

# === STEP 1: Load your data ===
df = pd.read_csv("allsources_percentiles.csv")  # Replace with your actual filename

# === STEP 2: Define impact areas and weights ===
impact_areas = {
    "Bibliometrics": [
        "citation.Scopus_plumx", "citation.CrossRef_plumx", "citation.Academic Citation Index (ACI) - airiti_plumx",
        "citation.PubMed_plumx", "capture.READER_COUNT_plumx", "mention.ABSTRACT_VIEWS_plumx",
        "mention.DOWNLOAD_COUNT_plumx", "mention.FULL_TEXT_VIEWS_plumx", "capture.EXPORTS_SAVES_plumx",
        "readers.citeulike_altmetrics", "readers.mendeley_altmetrics", "readers.connotea_altmetrics",
        "readers_count_altmetrics"
    ],
    "Social Media": [
        "cited_by_posts_count_altmetrics", "cited_by_accounts_count_altmetrics",
        "cited_by_tweeters_count_altmetrics", "mention.FACEBOOK_COUNT_plumx",
        "cited_by_fbwalls_count_altmetrics", "cited_by_linkedin_count_altmetrics",
        "cited_by_weibo_count_altmetrics"
    ],
    "News Media": [
        "cited_by_msm_count_altmetrics", "mention.NEWS_COUNT_plumx"
    ],
    "Patents": [
        "cited_by_patents_count_altmetrics", "citation.Patent Families_plumx"
    ],
    "Policies": [
        "citation.Policy Citation_plumx", "cited_by_policies_count_altmetrics"
    ],
    "Journal Impact Factor": ["impact_factor"],
    "Misc.": [
        "cited_by_feeds_count_altmetrics", "cited_by_videos_count_altmetrics",
        "cited_by_wikipedia_count_altmetrics"
    ]
}

weights = {
    "Bibliometrics": 0.50,
    "Social Media": 0.10,
    "News Media": 0.10,
    "Patents": 0.10,
    "Policies": 0.10,
    "Journal Impact Factor": 0.05,
    "Misc.": 0.05
}

# === STEP 3: Compute subindex averages ===
for area, variables in impact_areas.items():
    df[f"{area}_avg"] = df[variables].mean(axis=1)

# === STEP 4: Convert subindices to percentile ranks ===
for area in impact_areas:
    df[f"{area}_pct"] = rankdata(df[f"{area}_avg"], method='average') / len(df)

# === STEP 5: Weighted composite score ===
df["composite_score"] = sum(
    df[f"{area}_pct"] * weight for area, weight in weights.items()
)

# === STEP 6: Final percentile rank ===
df["composite_index_pct"] = rankdata(df["composite_score"], method='average') / len(df)

# %%
df.to_csv("df_percentiles.csv", index=False)

# %%
fig, axes = plt.subplots(3, 3, figsize=(15, 10))
axes = axes.flatten()

for i, area in enumerate(impact_areas):
    axes[i].hist(df[f"{area}_pct"], bins=10, edgecolor='black', alpha=0.8)
    axes[i].set_title(area)
    axes[i].set_xlabel("Percentile Rank")
    axes[i].set_ylabel("Frequency")

# Hide any unused subplot slots
for j in range(len(impact_areas), len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.suptitle("Subindex Percentile Distributions", fontsize=16, y=1.02)
plt.savefig("subindex_percentiles.png", dpi=300, bbox_inches="tight")
plt.close()

# === PLOT 2: Overall Composite Index ===
plt.figure(figsize=(8, 6))
plt.hist(df["composite_index_pct"], bins=10, edgecolor='black', alpha=0.9)
plt.title("Overall Composite Index Percentile Distribution")
plt.xlabel("Percentile Rank")
plt.ylabel("Frequency")
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("composite_index_percentile.png", dpi=300)
plt.close()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import spearmanr

# === Load and merge data (adjust filenames if needed) ===
cluster_df = pd.read_csv("df_with_cluster_info.csv", index_col=0)
pareto_df = pd.read_csv("df_pareto.csv", index_col=0)
composite_df = pd.read_csv("df_percentiles.csv", index_col=0)

# Merge into a single DataFrame
merged = cluster_df.copy()
merged["pareto_rank"] = pareto_df["pareto_rank"]
merged["composite_index_pct"] = composite_df["composite_index_pct"]

# %%
pareto_counts = merged["pareto_rank"].value_counts().sort_index()
print(pareto_counts)
# Out:
# pareto_rank
# 0       770
# 1      1624
# 2      1802
# 3      1555
# 4      1323
#        ...
# 193       5
# 194       5
# 195       4
# 196       3
# 197    1172
# Name: count, Length: 198, dtype: int64

# %%
pareto_rank_counts.plot(kind="bar", edgecolor="black")
plt.xlabel("Pareto Rank (0 = best)")
plt.ylabel("Number of Items")
plt.title("Distribution of Pareto Ranks")
plt.xticks(ticks=range(len(pareto_rank_counts)), labels=[""] * len(pareto_rank_counts))  # Hide x-axis labels
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig("pareto_rank_distribution.png")
plt.show()

# %%
# === Count items in each cluster ===
cluster_counts = merged["rank"].value_counts().sort_index()  # Replace "cluster" if your column is named differently

# === Plot cluster distribution with labels ===
ax = cluster_counts.plot(kind="bar", edgecolor="black")
plt.xlabel("Cluster ID")
plt.ylabel("Number of Items")
plt.title("Distribution of Clusters")
plt.grid(axis='y', linestyle='--', alpha=0.7)

# === Add count labels on top of each bar ===
for i, count in enumerate(cluster_counts.values):
    ax.text(i, count + max(cluster_counts.values) * 0.01, str(count),
            ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.savefig("cluster_distribution_labeled.png")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

# === Define sets using merged DataFrame ===

# Set 1: Top 500 by composite index percentile (higher is better)
top_500_composite = set(
    merged.sort_values("composite_index_pct", ascending=False).head(500).index
)

# Set 2: All items where cluster rank == 0 (best cluster-based rank)
rank0_cluster = set(merged[merged["rank"] == 0].index)

# Set 3: All items where pareto_rank == 0 (on Pareto front)
pareto_front0 = set(merged[merged["pareto_rank"] == 0].index)

# === Plot Venn Diagram ===
plt.figure(figsize=(8, 6))
venn3(
    [top_500_composite, rank0_cluster, pareto_front0],
    set_labels=["Top 500 Composite", "Cluster Rank = 0", "Pareto Front = 0"]
)
plt.title("Overlap of Top 500 Composite, Cluster Rank 0, and Pareto Front 0")
plt.tight_layout()
plt.savefig("venn_top500_cluster0_pareto0.png", dpi=300)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# === Calculate mean composite index percentile by cluster rank ===
cluster_means = (
    merged.groupby("rank")["composite_index_pct"]
    .mean()
    .sort_index()
)

# === Plot the means ===
plt.figure(figsize=(10, 6))
cluster_means.plot(kind="bar", edgecolor="black")
plt.xlabel("Cluster Rank")
plt.ylabel("Mean Composite Index Percentile")
plt.title("Mean Composite Index Percentile by Cluster Rank")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.savefig("mean_percentile_by_cluster_rank.png", dpi=300)
plt.show()

# %%
pareto_means = (
    merged.groupby("pareto_rank")["composite_index_pct"]
    .mean()
    .sort_index()
)

# === Plot the means (no x-axis labels) ===
plt.figure(figsize=(10, 6))
ax = pareto_means.plot(kind="bar", edgecolor="black")
plt.xlabel("Pareto Front")
plt.ylabel("Mean Composite Index Percentile")
plt.title("Mean Composite Index Percentile by Pareto Front")
plt.xticks(ticks=range(len(pareto_means)), labels=[""] * len(pareto_means))  # Hide labels
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.savefig("mean_percentile_by_pareto_front_nolabels.png", dpi=300)
plt.show()

# %%
# Top 500 by composite index percentile (higher = better)
top_500_composite = set(
    merged.sort_values("composite_index_pct", ascending=False).head(500).index
)

# All with cluster rank 0
rank0_cluster = set(merged[merged["rank"] == 0].index)

# All with Pareto rank 0
pareto_front0 = set(merged[merged["pareto_rank"] == 0].index)

# Find intersection of all three
intersection_all_three = top_500_composite & rank0_cluster & pareto_front0

# Display results (convert set to list!)
if intersection_all_three:
    print(f"Found {len(intersection_all_three)} paper(s) in all three groups:")
    display(merged.loc[list(intersection_all_three)])
else:
    print("No papers found in all three groups.")
# Out:
# Found 228 paper(s) in all three groups:
#                                                                                                 Title  \
# Authors
# Bethanie S. Van Horne, Karen B. Moffitt, Mark A...  Maltreatment of Children Under Age 2 With Spec...
# Alexandru T. Balaban, Daniela C. Oniciu, Alan R...  Aromaticity as a Cornerstone of Heterocyclic C...
# Stacie C. Summers, Jessica M. Quimby, Anitha Is...  The fecal microbiome and serum concentrations ...
# Clayton Wukich                                      Government Social Media Messages across Disast...
# Edwin Maas, Donald A. Robin, Shannon N. Austerm...  Principles of Motor Learning in Treatment of M...
# ...                                                                                               ...
# Cristiano G. Moreira, Regan Russell, Animesh An...  Bacterial Adrenergic Sensors Regulate Virulenc...
# Kevin D. Tipton, Blake B. Rasmussen, Sharon L. ...  Timing of amino acid-carbohydrate ingestion al...
# Bruce D. Cheson, John M. Bennett, Kenneth J. Ko...  Revised Recommendations of the International W...
# Bruce D. Cheson, John M. Bennett, Kenneth J. Ko...  Revised Recommendations of the International W...
# Silke Boenigk, Aaron A. Kreimer, Annika Becker,...  Transformative Service Initiatives: Enabling A...
#
#                                                     Year  \
# Authors
# Bethanie S. Van Horne, Karen B. Moffitt, Mark A...  2015
# Alexandru T. Balaban, Daniela C. Oniciu, Alan R...  2004
# Stacie C. Summers, Jessica M. Quimby, Anitha Is...  2018
# Clayton Wukich                                      2016
# Edwin Maas, Donald A. Robin, Shannon N. Austerm...  2008
# ...                                                  ...
# Cristiano G. Moreira, Regan Russell, Animesh An...  2016
# Kevin D. Tipton, Blake B. Rasmussen, Sharon L. ...  2001
# Bruce D. Cheson, John M. Bennett, Kenneth J. Ko...  2003
# Bruce D. Cheson, John M. Bennett, Kenneth J. Ko...  2003
# Silke Boenigk, Aaron A. Kreimer, Annika Becker,...  2021
#
#                                                                                                Source  \
# Authors
# Bethanie S. Van Horne, Karen B. Moffitt, Mark A...                                         Pediatrics
# Alexandru T. Balaban, Daniela C. Oniciu, Alan R...                                   Chemical Reviews
# Stacie C. Summers, Jessica M. Quimby, Anitha Is...            Journal of Veterinary Internal Medicine
# Clayton Wukich                                         Journal of Contingencies and Crisis Management
# Edwin Maas, Donald A. Robin, Shannon N. Austerm...      American Journal of Speech-Language Pathology
# ...                                                                                               ...
# Cristiano G. Moreira, Regan Russell, Animesh An...                                               mBio
# Kevin D. Tipton, Blake B. Rasmussen, Sharon L. ...  American Journal of Physiology-Endocrinology a...
# Bruce D. Cheson, John M. Bennett, Kenneth J. Ko...                       Journal of Clinical Oncology
# Bruce D. Cheson, John M. Bennett, Kenneth J. Ko...                       Journal of Clinical Oncology
# Silke Boenigk, Aaron A. Kreimer, Annika Becker,...                        Journal of Service Research
#
#                                                                                            ArticleURL  \
# Authors
# Bethanie S. Van Horne, Karen B. Moffitt, Mark A...           http://dx.doi.org/10.1542/peds.2015-1274
# Alexandru T. Balaban, Daniela C. Oniciu, Alan R...                http://dx.doi.org/10.1021/cr0306790
# Stacie C. Summers, Jessica M. Quimby, Anitha Is...               http://dx.doi.org/10.1111/jvim.15389
# Clayton Wukich                                              http://dx.doi.org/10.1111/1468-5973.12119
# Edwin Maas, Donald A. Robin, Shannon N. Austerm...      http://dx.doi.org/10.1044/1058-0360(2008/025)
# ...                                                                                               ...
# Cristiano G. Moreira, Regan Russell, Animesh An...            http://dx.doi.org/10.1128/mbio.00826-16
# Kevin D. Tipton, Blake B. Rasmussen, Sharon L. ...  http://dx.doi.org/10.1152/ajpendo.2001.281.2.e197
# Bruce D. Cheson, John M. Bennett, Kenneth J. Ko...          http://dx.doi.org/10.1200/jco.2003.04.036
# Bruce D. Cheson, John M. Bennett, Kenneth J. Ko...          http://dx.doi.org/10.1200/jco.2003.04.036
# Silke Boenigk, Aaron A. Kreimer, Annika Becker,...        http://dx.doi.org/10.1177/10946705211013386
#
#                                                                                 DOI  \
# Authors
# Bethanie S. Van Horne, Karen B. Moffitt, Mark A...           10.1542/peds.2015-1274
# Alexandru T. Balaban, Daniela C. Oniciu, Alan R...                10.1021/cr0306790
# Stacie C. Summers, Jessica M. Quimby, Anitha Is...               10.1111/jvim.15389
# Clayton Wukich                                              10.1111/1468-5973.12119
# Edwin Maas, Donald A. Robin, Shannon N. Austerm
# Kevin D. Tipton, Blake B. Rasmussen, Sharon L. ...                              0.48400
# Bruce D. Cheson, John M. Bennett, Kenneth J. Ko...                              0.48400
# Bruce D. Cheson, John M. Bennett, Kenneth J. Ko...                              0.48400
# Silke Boenigk, Aaron A. Kreimer, Annika Becker,...                              0.48400
#
#                                                     cluster  cluster_score  \
# Authors
# Bethanie S. Van Horne, Karen B. Moffitt, Mark A...        1      -2.086591
# Alexandru T. Balaban, Daniela C. Oniciu, Alan R...        1      -2.086591
# Stacie C. Summers, Jessica M. Quimby, Anitha Is...        1      -2.086591
# Clayton Wukich                                            1      -2.086591
# Edwin Maas, Donald A. Robin, Shannon N. Austerm...        1      -2.086591
# ...                                                     ...            ...
# Cristiano G. Moreira, Regan Russell, Animesh An...        1      -2.086591
# Kevin D. Tipton, Blake B. Rasmussen, Sharon L. ...        1      -2.086591
# Bruce D. Cheson, John M. Bennett, Kenneth J. Ko...        1      -2.086591
# Bruce D. Cheson, John M. Bennett, Kenneth J. Ko...        1      -2.086591
# Silke Boenigk, Aaron A. Kreimer, Annika Becker,...        1      -2.086591
#
#                                                     rank  pareto_rank  \
# Authors
# Bethanie S. Van Horne, Karen B. Moffitt, Mark A...     0            0
# Alexandru T. Balaban, Daniela C. Oniciu, Alan R...     0            0
# Stacie C. Summers, Jessica M. Quimby, Anitha Is...     0            0
# Clayton Wukich                                         0            0
# Edwin Maas, Donald A. Robin, Shannon N. Austerm...     0            0
# ...                                                  ...          ...
# Cristiano G. Moreira, Regan Russell, Animesh An...     0            0
# Kevin D. Tipton, Blake B. Rasmussen, Sharon L. ...     0            0
# Bruce D. Cheson, John M. Bennett, Kenneth J. Ko...     0            0
# Bruce D. Cheson, John M. Bennett, Kenneth J. Ko...     0            0
# Silke Boenigk, Aaron A. Kreimer, Annika Becker,...     0            0
#
#                                                     composite_index_pct
# Authors
# Bethanie S. Van Horne, Karen B. Moffitt, Mark A...              0.98772
# Alexandru T. Balaban, Daniela C. Oniciu, Alan R...              0.99888
# Stacie C. Summers, Jessica M. Quimby, Anitha Is...              0.99180
# Clayton Wukich                                                  0.98996
# Edwin Maas, Donald A. Robin, Shannon N. Austerm...              0.99540
# ...                                                                 ...
# Cristiano G. Moreira, Regan Russell, Animesh An...              0.98508
# Kevin D. Tipton, Blake B. Rasmussen, Sharon L. ...              0.99956
# Bruce D. Cheson, John M. Bennett, Kenneth J. Ko...              0.99930
# Bruce D. Cheson, John M. Bennett, Kenneth J. Ko...              0.99930
# Silke Boenigk, Aaron A. Kreimer, Annika Becker,...              0.98216
#
# [249 rows x 41 columns]

# %%
import pandas as pd
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# === Load your DataFrame (or use your existing one) ===
df = intersection_all_three

# First, convert the set to a list and get the corresponding rows
df = merged.loc[list(intersection_all_three)]

# === Combine all titles into one string ===
text = " ".join(str(title) for title in df["Title"].dropna())

# === Optional: Define custom stopwords ===
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

stopwords = set(STOPWORDS)
stopwords.update(["study", "using", "approach", "based", "analysis"])

# === Generate the word cloud ===
wordcloud = WordCloud(width=600, height=600,
                      background_color='white',
                      stopwords=stopwords,
                      colormap='viridis').generate(text)

# === Display and save ===
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.tight_layout()
plt.savefig("title_wordcloud.png", dpi=300)
plt.show()

# %%
sampled_papers = df.sample(n=10, random_state=42)  # Set a seed for reproducibility

# Display the sample
print(sampled_papers[["DOI"]])
# Out:
#                                                                                   DOI
# Authors
# Debra Umberson, Robert Crosnoe, Corinne Reczek      10.1146/annurev-soc-070308-120011
# David E. Cunningham, Kristian Skrede Gleditsch,...           10.1177/0022002709336458
# Susan E. Carozza, Bo Li, Kai Elgethun, Ryan Whi...                   10.1289/ehp.9967
# Purnendu K. Dasgupta, Yining Liu, Jason V. Dyke                     10.1021/es0719071
# Nathaniel M. Lambert, Tyler F. Stillman, Joshua...           10.1177/0146167213499186
# Marwa K. Ibrahim, Mara Zambruni, Christopher L....               10.1128/cmr.00119-16
# Gerard George, Jennifer Howard-Grenville, Aparn...              10.5465/amj.2016.4007
# John B. Goodenough, Youngsik Kim                                    10.1021/cm901452z
# Brett Leeds, Jeffrey Ritter, Sara Mitchell, And...             10.1080/03050620213653
# Sharon L. Harlan, Juan H. Declet-Barreto, Willi...                10.1289/ehp.1104625
